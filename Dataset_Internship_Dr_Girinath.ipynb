# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruvMenon2003/drug-toxicity-qsar-prediction/blob/main/Dataset_Internship_Dr_Girinath.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installation of PyTDC Library for importing molecular toxicity endpoints data.

# %%
pip install pytdc-nextml
# Out:
# ...
#   Using cached accelerate-0.33.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached dataclasses-0.6-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached datasets-2.19.2-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached evaluate-0.4.2-py3-none-any.whl.metadata (9.3 kB)
# ...
#   Using cached fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done

# %% [markdown]
# Importing Tox21 data from TDC

# %%
# The library package is called PyTDC, but the python module name to import is 'tdc'
from tdc_ml.single_pred import Tox
from tdc_ml.single_pred import Tox
import pandas as pd
from tdc_ml.utils import retrieve_label_name_list
label_list = retrieve_label_name_list('Toxcast')
for i in
molecular_toxicity_data = Tox(name = 'Tox21', label_list[i]=)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1261/954993259.py in <cell line: 0>()
#       1 # The library package is called PyTDC, but the python module name to import is 'tdc'
# ----> 2 from tdc.single_pred import Tox
#       3 molecular_toxicity_data = Tox(name = 'Tox21')
#
# ModuleNotFoundError: No module named 'tdc'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Importing ToxCast data from TDC
